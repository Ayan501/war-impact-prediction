# %%
import pandas as pd
import os

# notebook folder se ek upar jaao, phir Data/raw_data
RAW = os.path.join(os.getcwd(), "..", "Data", "raw_data")

def load_all_data():
    df_sugar      = pd.read_csv(os.path.join(RAW, "sugar price.csv"))
    df_silver     = pd.read_csv(os.path.join(RAW, "silver price.csv"),sep=',')
    df_gold       = pd.read_csv(os.path.join(RAW, "gold price.csv"),sep=',')
    df_wheat      = pd.read_csv(os.path.join(RAW, "wheat value.csv"),sep='\t')
    df_soyaoil    = pd.read_csv(os.path.join(RAW, "soya oil.csv"),sep='\t')
    df_naturalGas = pd.read_csv(os.path.join(RAW, "natural gas price.csv"),sep='\t')
    df_inflation  = pd.read_csv(os.path.join(RAW, "inflation.csv"))
    df_crudeOil   = pd.read_csv(os.path.join(RAW, "crude oil price.csv"),sep='\t')
    df_conflict   = pd.read_csv(os.path.join(RAW, "conflict_data.csv"))
    # df1 = pd.read_excel(os.path.join(RAW, "2025_ucdp-prio-acd-251.xlsx"),sep='\t')
    # df2 = pd.read_excel(os.path.join(RAW, "2025_ucdp-brd-dyadic-251.xlsx"),sep='\t')

    return {
        # "ucdp_dyadic":   df1,
        # "ucdp_conflict": df2,
        "sugar":         df_sugar,
        "inflation":     df_inflation,
        "conflict":      df_conflict,
        "crude_oil":     df_crudeOil,
        "natural_gas":   df_naturalGas,

        "wheat":         df_wheat,
        "soya_oil":      df_soyaoil,
        "gold":          df_gold,
        "silver":        df_silver
    }
